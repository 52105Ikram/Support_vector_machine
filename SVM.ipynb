# %%
# Demonstration of SVM with high-dimensional data,
# regularization, and dimensionality reduction

import numpy as np
from sklearn.datasets import make_classification
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# Create high dimentional dataset (100 features)

X, y = make_classification(
n_samples = 1000,
n_features = 100, #very high dimention
n_informative = 10, # only 10 truly usful featues
n_redundant = 40,
n_repeated = 10,
random_state=42
)
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size = 0.2, random_state=42
)
print("original feature dimention:",X.shape[1])
# Out:
# original feature dimention: 100

# %%
# Base line svm (risk of overfiting)
svm_baseline = SVC(kernel="rbf",C=10) # weak regulariztion
svm_baseline.fit(x_train, y_train)
pred_base = svm_baseline.predict(x_test)
acc_base = accuracy_score(y_test, pred_base)
acc_base
# Out:
# 0.97

# %%
# Regularaized SVM (Strong regularization)
svm_reg = SVC(kernel="rbf",C=1)
svm_reg.fit(x_train, y_train)
pred_reg = svm_reg.predict(x_test)
acc_reg = accuracy_score(y_test, pred_reg)
acc_reg
# Out:
# 0.955

# %%
# dimention reduction : PCA
pca = PCA(n_components = 20) # reduce 100 -> 20 dimention
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

svm_pca = SVC(kernel="rbf", C=1)
svm_pca.fit(X_train_pca, y_train)
pred_pca = svm_pca.predict(X_test_pca)
acc_pca = accuracy_score(y_test, pred_pca)
acc_pca

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
